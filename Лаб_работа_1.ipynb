# %% [markdown]
# <a href="https://colab.research.google.com/github/RomashkaPolli/proga/blob/main/%D0%9B%D0%B0%D0%B1_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_01_06.
# Выполнил: Михалева П.В.
# Группа: ЦИБ-251
a = int(input())
b = int(input())
m = int(input())
n = int(input())

x = -b / a

is_ok = m <= x <= n

print("Попадает:", is_ok)
